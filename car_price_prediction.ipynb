# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/content/car data.csv')
data
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Selling_type Transmission  Owner
# 0         Dealer       Manual      0
# 1         Dealer       Manual      0
# 2         Dealer       Manual      0
# 3         Dealer       Manual      0
# 4         Dealer       Manual      0
# ..           ...          ...    ...
# 296       Dealer       Manual      0
# 297       Dealer       Manual      0
# 298       Dealer       Manual      0
# 299       Dealer       Manual      0
# 300       Dealer       Manual      0
#
# [301 rows x 9 columns]

# %%
data.shape
# Out:
# (301, 9)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Driven_kms     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Selling_type   301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
data.describe()
# Out:
#               Year  Selling_Price  Present_Price     Driven_kms       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.642584   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
data.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Driven_kms       0
# Fuel_Type        0
# Selling_type     0
# Transmission     0
# Owner            0
# dtype: int64

# %% [markdown]
# **value_counts() gives the unique values of that column**

# %%
data.Year.value_counts()
# Out:
# Year
# 2015    61
# 2016    50
# 2014    38
# 2017    35
# 2013    33
# 2012    23
# 2011    19
# 2010    15
# 2008     7
# 2009     6
# 2006     4
# 2005     4
# 2003     2
# 2007     2
# 2018     1
# 2004     1
# Name: count, dtype: int64

# %%
col = list(data.columns)
col
# Out:
# ['Car_Name',
#  'Year',
#  'Selling_Price',
#  'Present_Price',
#  'Driven_kms',
#  'Fuel_Type',
#  'Selling_type',
#  'Transmission',
#  'Owner']

# %%
for i in col:
    if(data[i].dtype == 'int64' or data[i].dtype == 'float64'):
        plt.hist(data[i])
        plt.xlabel(i)
        plt.ylabel('count')
        plt.show()

# %%
for i in col:
  if data[i].dtype == "int64" or data[i].dtype =='float64':
    plt.boxplot(data[i])
    plt.xlabel(i)
    plt.ylabel('count')
    plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
data['Car_Name'] = le.fit_transform(data['Car_Name'])
data['Fuel_Type'] = le.fit_transform(data['Fuel_Type'])
data['Selling_type'] = le.fit_transform(data['Selling_type'])
data['Transmission'] = le.fit_transform(data['Transmission'])

data['Car_Name'] = data['Car_Name'].astype(int)
data['Fuel_Type'] = data['Fuel_Type'].astype(int)
data['Selling_type'] = data['Selling_type'].astype(int)
data['Transmission'] = data['Transmission'].astype(int)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    int64
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Driven_kms     301 non-null    int64
#  5   Fuel_Type      301 non-null    int64
#  6   Selling_type   301 non-null    int64
#  7   Transmission   301 non-null    int64
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 21.3 KB

# %%
data.describe()
# Out:
#          Car_Name         Year  Selling_Price  Present_Price     Driven_kms  \
# count  301.000000   301.000000     301.000000     301.000000     301.000000
# mean    62.571429  2013.627907       4.661296       7.628472   36947.205980
# std     25.573535     2.891554       5.082812       8.642584   38886.883882
# min      0.000000  2003.000000       0.100000       0.320000     500.000000
# 25%     47.000000  2012.000000       0.900000       1.200000   15000.000000
# 50%     69.000000  2014.000000       3.600000       6.400000   32000.000000
# 75%     82.000000  2016.000000       6.000000       9.900000   48767.000000
# max     97.000000  2018.000000      35.000000      92.600000  500000.000000
#
#         Fuel_Type  Selling_type  Transmission       Owner
# count  301.000000    301.000000    301.000000  301.000000
# mean     1.787375      0.352159      0.867110    0.043189
# std      0.425801      0.478439      0.340021    0.247915
# min      0.000000      0.000000      0.000000    0.000000
# 25%      2.000000      0.000000      1.000000    0.000000
# 50%      2.000000      0.000000      1.000000    0.000000
# 75%      2.000000      1.000000      1.000000    0.000000
# max      2.000000      1.000000      1.000000    3.000000

# %%
from sklearn.model_selection import train_test_split
x=data.drop(['Car_Name','Selling_Price'],axis=1)
y=data['Selling_Price']
x
# Out:
#      Year  Present_Price  Driven_kms  Fuel_Type  Selling_type  Transmission  \
# 0    2014           5.59       27000          2             0             1
# 1    2013           9.54       43000          1             0             1
# 2    2017           9.85        6900          2             0             1
# 3    2011           4.15        5200          2             0             1
# 4    2014           6.87       42450          1             0             1
# ..    ...            ...         ...        ...           ...           ...
# 296  2016          11.60       33988          1             0             1
# 297  2015           5.90       60000          2             0             1
# 298  2009          11.00       87934          2             0             1
# 299  2017          12.50        9000          1             0             1
# 300  2016           5.90        5464          2             0             1
#
#      Owner
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
# ..     ...
# 296      0
# 297      0
# 298      0
# 299      0
# 300      0
#
# [301 rows x 7 columns]

# %%
y
# Out:
# 0       3.35
# 1       4.75
# 2       7.25
# 3       2.85
# 4       4.60
#        ...
# 296     9.50
# 297     4.00
# 298     3.35
# 299    11.50
# 300     5.30
# Name: Selling_Price, Length: 301, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train= sc.fit_transform(x_train)
x_test=sc.fit_transform(x_test)
x_train
# Out:
# array([[ 0.14709233,  0.14665281,  1.05706025, ..., -0.7540739 ,
#          0.37073003, -0.1393466 ],
#        [-0.53179535, -0.35559878, -0.3529268 , ..., -0.7540739 ,
#          0.37073003, -0.1393466 ],
#        [ 1.16542386,  3.19364579, -0.77406088, ..., -0.7540739 ,
#         -2.69738059, -0.1393466 ],
#        ...,
#        [ 0.48653618, -0.63797578, -0.58381453, ...,  1.32612997,
#          0.37073003, -0.1393466 ],
#        [-2.56845841, -0.38684999,  0.62900596, ..., -0.7540739 ,
#          0.37073003, -0.1393466 ],
#        [ 0.14709233, -0.77860623, -0.59094876, ...,  1.32612997,
#          0.37073003, -0.1393466 ]])

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train= sc.fit_transform(x_train)
x_test=sc.fit_transform(x_test)
x_train
# Out:
# array([[ 0.14709233,  0.14665281,  1.05706025, ..., -0.7540739 ,
#          0.37073003, -0.1393466 ],
#        [-0.53179535, -0.35559878, -0.3529268 , ..., -0.7540739 ,
#          0.37073003, -0.1393466 ],
#        [ 1.16542386,  3.19364579, -0.77406088, ..., -0.7540739 ,
#         -2.69738059, -0.1393466 ],
#        ...,
#        [ 0.48653618, -0.63797578, -0.58381453, ...,  1.32612997,
#          0.37073003, -0.1393466 ],
#        [-2.56845841, -0.38684999,  0.62900596, ..., -0.7540739 ,
#          0.37073003, -0.1393466 ],
#        [ 0.14709233, -0.77860623, -0.59094876, ...,  1.32612997,
#          0.37073003, -0.1393466 ]])

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
predictions=model.predict(x_test)

# %%
from sklearn.metrics import r2_score
r2=r2_score(y_test,predictions)
print("r2 score is:{}".format(r2))

adj_r2=1-(1-r2)*len(y_train)/(len(y_train)-x_train.shape[1]-1)
print("adjusted r2 score:{}".format(adj_r2))
# Out:
# r2 score is:0.9082030341748316
# adjusted r2 score:0.9050376215601706

# %%
from sklearn.metrics import *
rmse_on_test=mean_squared_error(y_test,predictions,squared=False)
print("root mean square error on test data:{}".format(rmse_on_test))
# Out:
# root mean square error on test data:1.523279734306078

# %%
train_predict=model.predict(x_train)

# %%
rmse_on_train=mean_squared_error(y_train,train_predict, squared=False)
print("root mean square error on train data:{}".format(rmse_on_train))
# Out:
# root mean square error on train data:1.8438051369414459

# %%
mape_on_test=mean_absolute_percentage_error(y_test,predictions)
print("mean absolute percentage error on test data:{}".format(mape_on_test))
# Out:
# mean absolute percentage error on test data:1.2205711240735335

# %%
mape_on_train=mean_absolute_percentage_error(y_train,train_predict)
print("mean absolute percentage error on train data:{}".format(mape_on_train))
# Out:
# mean absolute percentage error on train data:1.2850606293933695

# %%
error_prediction=pd.DataFrame(columns=['Actual_data','Prediction_data'])
error_prediction['Actual_data']=y_test
error_prediction['Prediction_data']=predictions
error_prediction['error']=error_prediction['Actual_data']-error_prediction['Prediction_data']
error_prediction.head()
# Out:
#      Actual_data  Prediction_data     error
# 223         8.25         6.896611  1.353389
# 150         0.50        -1.498636  1.998636
# 226         5.25         3.870427  1.379573
# 296         9.50         8.840910  0.659090
# 52         18.00        15.165182  2.834818
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Actual_data'].plot(kind='hist', bins=20, title='Actual_data')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['Prediction_data'].plot(kind='hist', bins=20, title='Prediction_data')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['error'].plot(kind='hist', bins=20, title='error')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_3.plot(kind='scatter', x='Actual_data', y='Prediction_data', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_4.plot(kind='scatter', x='Prediction_data', y='error', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_5['Actual_data'].plot(kind='line', figsize=(8, 4), title='Actual_data')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_6['Prediction_data'].plot(kind='line', figsize=(8, 4), title='Prediction_data')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_7['error'].plot(kind='line', figsize=(8, 4), title='error')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
plt.figure(figsize=(5,5))
plt.scatter(error_prediction['Actual_data'],error_prediction['Prediction_data'],c='crimson')
p1=max(max(error_prediction['Prediction_data']),max(error_prediction['Actual_data']))
p2=min(min(error_prediction['Prediction_data']),min(error_prediction['Actual_data']))
plt.plot([p1,p2],[p1,p2],'-g')
plt.title('actual_values vs predicted_values')
plt.xlabel('actual_values')
plt.ylabel('predicted_values')
plt.show()

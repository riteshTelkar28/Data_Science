# %% [markdown]
# <a href="https://colab.research.google.com/github/riteshTelkar28/Data_Science/blob/main/Linear_Regression_training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('/content/data.csv')
data
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %% [markdown]
# **EDA started**

# %%
data.shape
# Out:
# (30, 2)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     float64
# dtypes: float64(2)
# memory usage: 608.0 bytes

# %%
data.describe()
# Out:
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.313333   76003.000000
# std           2.837888   27414.429785
# min           1.100000   37731.000000
# 25%           3.200000   56720.750000
# 50%           4.700000   65237.000000
# 75%           7.700000  100544.750000
# max          10.500000  122391.000000

# %%
data.isnull().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
plt.figure(figsize=(15,4))
plt.subplot(1,4,1)
sns.boxplot(data['YearsExperience'])
plt.subplot(1,4,2)
sns.boxplot(data['Salary'])
plt.show()

# %%
data.corr()
# Out:
#                  YearsExperience    Salary
# YearsExperience         1.000000  0.978242
# Salary                  0.978242  1.000000

# %% [markdown]
# **heatmap :- to represent more common values or higher activities brighter colors basically reddish colors are used**

# %%
plt.figure(figsize=(20,8))
sns.heatmap(data.corr(), annot = True)
plt.show()

# %%
y=data[['Salary']]
x=data[['YearsExperience']]
from sklearn.linear_model import *
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=.40,random_state=1)
lr=LinearRegression()
lr.fit(x_train,y_train)
y_pred = lr.predict(x_test)
y_pred
# Out:
# array([[ 74161.91026747],
#        [ 89966.88467069],
#        [ 61869.1523983 ],
#        [ 80308.28920206],
#        [ 67137.47719937],
#        [ 87332.72227016],
#        [111040.18387499],
#        [ 45186.12386157],
#        [104015.75080689],
#        [ 96991.31773879],
#        [ 99625.48013933],
#        [ 46942.23212859]])

# %%
from sklearn.metrics import *

# %%
accuracy = r2_score(y_test,y_pred)
accuracy
# Out:
# 0.906786576108805
